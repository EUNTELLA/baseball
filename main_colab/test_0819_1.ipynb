# %% [markdown]
# <a href="https://colab.research.google.com/github/EUNTELLA/baseball/blob/main/test_0819_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# !python -c "import catboost; print('catboost:', catboost.__version__)"
# !python -c "import torch; print('torch cuda:', torch.cuda.is_available()); print('cuda:', torch.version.cuda)"
# Out:
# Wed Aug 19 11:21:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -q catboost==1.2.8
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/baseball /content/dataset /content/league_build
# !git clone https://github.com/EUNTELLA/baseball.git /content/baseball
# !unzip -q -o /content/drive/MyDrive/open.zip -d /content/dataset
# Out:
# Cloning into '/content/baseball'...
# remote: Enumerating objects: 665, done.
# remote: Counting objects: 100% (665/665), done.
# remote: Compressing objects: 100% (448/448), done.
# remote: Total 665 (delta 302), reused 523 (delta 170), pack-reused 0 (from 0)
# Receiving objects: 100% (665/665), 42.70 MiB | 31.27 MiB/s, done.
# Resolving deltas: 100% (302/302), done.

# %%
# %cd /content/baseball
# !git pull

# !python /content/baseball/0819/01_catboost_residual_differential_screen_colab.py \
  --train /content/dataset/data/train.csv \
  --output /content/drive/MyDrive/0819_catboost_residual_differential.json \
  --task-type GPU
# Out:
# /content/baseball
# Already up to date.
# fold=2021 seed=42 iter=113 sec=13.2
# fold=2021 seed=7 iter=157 sec=14.5
# fold=2021 seed=2024 iter=114 sec=12.9
# fold=2022 seed=42 iter=315 sec=31.4
# fold=2022 seed=7 iter=215 sec=23.4
# fold=2022 seed=2024 iter=232 sec=25.5
# fold=2023 seed=42 iter=1 sec=14.3
# fold=2023 seed=7 iter=1 sec=14.5
# fold=2023 seed=2024 iter=2 sec=14.4
# fold=2024 seed=42 iter=286 sec=50.4
# fold=2024 seed=7 iter=206 sec=43.0
# fold=2024 seed=2024 iter=267 sec=50.8
# fold=2023 all_three BSS delta=+31.77 corr2 delta=+31.93
# fold=2024 all_three BSS delta=+36.29 corr2 delta=+36.81
# {
#   "all_three_bss_deltas": [
#     31.769376040791112,
#     36.294317850638095
#   ],
#   "decision": "continue_full_997_pipeline"
# }
# saved: /content/drive/MyDrive/0819_catboost_residual_differential.json

# %%
# %cd /content/baseball
# !git pull

# !python /content/baseball/0819/02_residual_differential_full_pipeline_colab.py \
  --train /content/dataset/data/train.csv \
  --output /content/drive/MyDrive/0819_residual_differential_full_pipeline.json \
  --task-type GPU
# Out:
# /content/baseball
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 7 (delta 3), reused 7 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 5.04 KiB | 1.26 MiB/s, done.
# From https://github.com/EUNTELLA/baseball
#    1c2d2e6..edab6d2  main       -> origin/main
# Updating 1c2d2e6..edab6d2
# Fast-forward
#  ...02_residual_differential_full_pipeline_colab.py | 250 +++++++++++++++++++++
#  0819/README.md                                     |  23 ++
#  doc/EXPERIMENTS.md                                 |  14 ++
#  3 files changed, 287 insertions(+)
#  create mode 100644 0819/02_residual_differential_full_pipeline_colab.py
# source fold=2021 success inner seed=42 iter=113 sec=13.1
# source fold=2021 success inner seed=7 iter=157 sec=14.4
# source fold=2021 success inner seed=2024 iter=114 sec=12.4
# source fold=2022 success inner seed=42 iter=315 sec=30.0
# ...

# %%
# %cd /content/baseball
# !git pull

# !python /content/baseball/0819/03_build_residual_differential_submission_colab.py \
  --train /content/dataset/data/train.csv \
  --test /content/dataset/data/test.csv \
  --sample /content/dataset/data/sample_submission.csv \
  --report /content/drive/MyDrive/0819_residual_differential_build.json
# Out:
# /content/baseball
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 7 (delta 3), reused 7 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 5.73 KiB | 1.91 MiB/s, done.
# From https://github.com/EUNTELLA/baseball
#    edab6d2..7954a8f  main       -> origin/main
# Updating edab6d2..7954a8f
# Fast-forward
#  ...build_residual_differential_submission_colab.py | 244 +++++++++++++++++++++
#  0819/README.md                                     |  22 ++
#  doc/EXPERIMENTS.md                                 |  15 ++
#  3 files changed, 281 insertions(+)
#  create mode 100644 0819/03_build_residual_differential_submission_colab.py
# source fold=2023 seed=42 iter=1 sec=14.1
# source fold=2023 seed=7 iter=1 sec=14.4
# source fold=2023 seed=2024 iter=2 sec=14.5
# source fold=2023 seed=99 iter=1 sec=14.2
# source fold=2023 seed=1 iter=1 sec=14.4
# ...

# %%
# !cp /content/baseball/0819/results/submit_catboost_residual_differential.zip \
  /content/drive/MyDrive/submit_catboost_residual_differential.zip
